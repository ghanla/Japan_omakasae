# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\eric9\Downloads\df_text_combined.csv", encoding='utf-8')

df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
df_test_stg2 = pd.read_csv(r"C:\Users\eric9\Downloads\mercari-price-suggestion-challenge\test_stg2.tsv\test_stg2.tsv", sep='\t', encoding='utf-8')
df_test_stg2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3460725 entries, 0 to 3460724
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   test_id            int64
#  1   name               object
#  2   item_condition_id  int64
#  3   category_name      object
#  4   brand_name         object
#  5   shipping           int64
#  6   item_description   object
# dtypes: int64(3), object(4)
# memory usage: 184.8+ MB

# %%
df_test = pd.read_csv(r"C:\Users\eric9\Downloads\mercari-price-suggestion-challenge\test.tsv\test.tsv", sep='\t', encoding='utf-8')
df_test
# Out:
#         test_id                                      name  item_condition_id  \
# 0             0  Breast cancer "I fight like a girl" ring                  1
# 1             1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2             2                                 Coach bag                  1
# 3             3                             Floral Kimono                  2
# 4             4                          Life after Death                  3
# ...         ...                                       ...                ...
# 693354   693354             Quartz crystal on Flint stone                  1
# 693355   693355              It Cosmetics - Travel Bundle                  1
# 693356   693356                 Galaxy S8 hard shell case                  1
# 693357   693357                      Hi low floral kimono                  2
# 693358   693358     FREESHIP 2 Floral Scrub Tops, medium.                  2
#
# ...

# %%
df_sample = pd.read_csv(r"C:\Users\eric9\Downloads\mercari-price-suggestion-challenge\sample_submission.csv\sample_submission.csv", sep='\t', encoding='utf-8')

# %%
df_sample_stg2 = pd.read_csv(r"C:\Users\eric9\Downloads\mercari-price-suggestion-challenge\sample_submission_stg2.csv\sample_submission_stg2.csv", sep='\t', encoding='utf-8')

# %%
df_sample_stg2
# Out:
#           test_id,price
# 0              0,26.738
# 1              1,26.738
# 2              2,26.738
# 3              3,26.738
# 4              4,26.738
# ...                 ...
# 3460720  3460720,26.738
# 3460721  3460721,26.738
# 3460722  3460722,26.738
# 3460723  3460723,26.738
# 3460724  3460724,26.738
#
# [3460725 rows x 1 columns]

# %%
df_test[~df_test['name'].isin(df_test_stg2['name'])]
# Out:
# Empty DataFrame
# Columns: [test_id, name, item_condition_id, category_name, brand_name, shipping, item_description]
# Index: []

# %%
df #category_name '/' 분리. 필요.
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481661 entries, 0 to 1481660
# Data columns (total 13 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1481661 non-null  int64
#  1   name               1481661 non-null  object
#  2   item_condition_id  1481661 non-null  int64
#  3   category_name      1481661 non-null  object
#  4   brand_name         1481661 non-null  object
#  5   price              1481661 non-null  float64
#  6   shipping           1481661 non-null  int64
#  7   item_description   1481661 non-null  object
#  8   desc_length        1481661 non-null  int64
#  9   positive_count     1481661 non-null  int64
#  10  positive_words     1481661 non-null  object
#  11  negative_count     1481661 non-null  int64
#  12  negative_words     1481661 non-null  object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 147.0+ MB

# %%
df.describe() #price 좀 봐야할 것 같음 . train_id 중복 없음
# Out:
#            train_id  item_condition_id         price      shipping  \
# count  1.481661e+06       1.481661e+06  1.481661e+06  1.481661e+06
# mean   7.412437e+05       1.907322e+00  2.675329e+01  4.473257e-01
# std    4.279715e+05       9.031759e-01  3.859198e+01  4.972178e-01
# min    0.000000e+00       1.000000e+00  3.000000e+00  0.000000e+00
# 25%    3.705880e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412380e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111877e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00
#
#         desc_length  positive_count  negative_count
# count  1.481661e+06    1.481661e+06    1.481661e+06
# mean   2.568985e+01    8.417641e-01    2.342979e-01
# std    3.039537e+01    1.036294e+00    5.095033e-01
# min    1.000000e+00    0.000000e+00    0.000000e+00
# 25%    7.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
df['brand_name'].unique() # ...?
# Out:
# array(['unknown', 'razer', 'target', ..., 'astroglide', 'cumberland bay',
#        'kids only'], dtype=object)

# %%
df[df['brand_name'] == '...'] #...는 이하 생략이였다.
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, desc_length, positive_count, positive_words, negative_count, negative_words]
# Index: []

# %%
df['brand_name'].nunique() #one hot 진행하기에는 너무 많다..
# Out:
# 4808

# %%
df.isna().mean() # category_name은 분류 부분인데 내용이 없는 것은 이해가 되지 않는다. 나머지는 그럴 수 있다.
# Out:
# train_id             0.0
# name                 0.0
# item_condition_id    0.0
# category_name        0.0
# brand_name           0.0
# price                0.0
# shipping             0.0
# item_description     0.0
# desc_length          0.0
# positive_count       0.0
# positive_words       0.0
# negative_count       0.0
# negative_words       0.0
# dtype: float64

# %%
df['category_name'].fillna('NaN')
# Out:
# 0                                          men/tops/t-shirts
# 1          electronics/computers & tablets/components & p...
# 2                                women/tops & blouses/blouse
# 3                         home/home décor/home décor accents
# 4                                    women/jewelry/necklaces
#                                  ...
# 1481656                               women/dresses/mid-calf
# 1481657                             kids/girls 2t-5t/dresses
# 1481658       sports & outdoors/exercise/fitness accessories
# 1481659                   home/home décor/home décor accents
# 1481660                    women/women's accessories/wallets
# Name: category_name, Length: 1481661, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.scatter(range(len(df['price'])), df['price'], alpha=0.5)
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Scatter Plot of Price')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df[df['price'] <= 150]['price'], bins=50, kde=True, color='blue')

plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price Distribution of Products (under $150)")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df[df['price'] <= 750]['price'], bins=50, kde=True, color='blue')

plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Price Distribution of Products (under $750)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(df['price'], vert=True)  # vert=True는 세로 방향 박스플롯
plt.ylabel('Price')
plt.title('Box Plot of Price')
plt.show()

# %%
df['item_condition_id'].value_counts().plot(kind='bar', figsize=(10, 5))
plt.xlabel('item_condition_id')
plt.ylabel('Count')
plt.title('Category Count Bar Plot')
plt.xticks(rotation=0)  # x축 라벨 회전
plt.show()
#구간 분포 확인 완료

# %%
category = df['category_name'].str.split('/').apply(pd.Series)
category = category.applymap(lambda x: x.lower() if isinstance(x, str) else x)

category = category.rename(columns={0: 'main_category', 1: 'sub1_category', 2: 'sub2_category',  3: 'sub3_category', 4: 'sub4_category'})

# %%
category
# Out:
#              main_category        sub1_category        sub2_category  \
# 0                      men                 tops             t-shirts
# 1              electronics  computers & tablets   components & parts
# 2                    women       tops & blouses               blouse
# 3                     home           home décor   home décor accents
# 4                    women              jewelry            necklaces
# ...                    ...                  ...                  ...
# 1481656              women              dresses             mid-calf
# 1481657               kids          girls 2t-5t              dresses
# 1481658  sports & outdoors             exercise  fitness accessories
# 1481659               home           home décor   home décor accents
# 1481660              women  women's accessories              wallets
#
#         sub3_category sub4_category
# 0                 NaN           NaN
# 1                 NaN           NaN
# ...

# %%
df = pd.merge(df, category, left_index=True, right_index=True, how='inner')

# %%
df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = category[category['main_category'] == 'Electronics']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['sub1_category'].value_counts()

# 결과 출력
print(category_counts)
# Out:
# Series([], Name: count, dtype: int64)

# %%
category
# Out:
#              main_category        sub1_category        sub2_category  \
# 0                      men                 tops             t-shirts
# 1              electronics  computers & tablets   components & parts
# 2                    women       tops & blouses               blouse
# 3                     home           home décor   home décor accents
# 4                    women              jewelry            necklaces
# ...                    ...                  ...                  ...
# 1481656              women              dresses             mid-calf
# 1481657               kids          girls 2t-5t              dresses
# 1481658  sports & outdoors             exercise  fitness accessories
# 1481659               home           home décor   home décor accents
# 1481660              women  women's accessories              wallets
#
#         sub3_category sub4_category
# 0                 NaN           NaN
# 1                 NaN           NaN
# ...

# %%
category['sub4_category'].unique() #2개
# Out:
# array([nan, 'ebook readers', 'ebook access'], dtype=object)

# %%
category['sub3_category'].unique() #6개
# Out:
# array([nan, 'tablet', 'ballet', 'outdoor games', 'baseball', 'bomber',
#        'serving'], dtype=object)

# %%
category[(category['main_category'] == 'Electronics') & (category['sub4_category'] == 'eBook Readers')]
# Out:
# Empty DataFrame
# Columns: [main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
category[(category['main_category'] == 'Electronics') & (category['sub4_category'] == 'eBook Access')]
# Out:
# Empty DataFrame
# Columns: [main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
df[(df['main_category'] == 'Electronics') & (df['sub4_category'] == 'eBook Access')]
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, desc_length, positive_count, positive_words, negative_count, negative_words, main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
df[(df['main_category'] == 'Electronics') & (df['sub4_category'] == 'eBook Access')].sort_values(by='price', ascending=True)
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, desc_length, positive_count, positive_words, negative_count, negative_words, main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
df[(df['main_category'] == 'Electronics') & (df['sub4_category'] == 'eBook Readers')].sort_values(by='price', ascending=True)
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, desc_length, positive_count, positive_words, negative_count, negative_words, main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
#price가 0인 값들이 나타남. 소분류가 의미가 있나 싶은 상황이 보임
df.describe()
# Out:
#            train_id  item_condition_id         price      shipping  \
# count  1.481661e+06       1.481661e+06  1.481661e+06  1.481661e+06
# mean   7.412437e+05       1.907322e+00  2.675329e+01  4.473257e-01
# std    4.279715e+05       9.031759e-01  3.859198e+01  4.972178e-01
# min    0.000000e+00       1.000000e+00  3.000000e+00  0.000000e+00
# 25%    3.705880e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412380e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111877e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00
#
#         desc_length  positive_count  negative_count
# count  1.481661e+06    1.481661e+06    1.481661e+06
# mean   2.568985e+01    8.417641e-01    2.342979e-01
# std    3.039537e+01    1.036294e+00    5.095033e-01
# min    1.000000e+00    0.000000e+00    0.000000e+00
# 25%    7.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
df[df['price'] <= 0].sort_values(by='price', ascending=True)
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, desc_length, positive_count, positive_words, negative_count, negative_words, main_category, sub1_category, sub2_category, sub3_category, sub4_category]
# Index: []

# %%
df[df['price'] > 0] #df = df.drop(df[df['price'] <= 0].index)
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
df['main_category'].unique()
# Out:
# array(['men', 'electronics', 'women', 'home', 'sports & outdoors',
#        'vintage & collectibles', 'beauty', 'other', 'kids', 'unknown',
#        'handmade'], dtype=object)

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = category[category['main_category'] == 'Other']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['sub1_category'].unique()

# 결과 출력
print(category_counts)
# Out:
# []

# %%
df_filtered = df[df['price'] > 0]

# %%
before_df = df_filtered.copy()  # 동일한 필터링된 데이터를 another 변수에 저장
df = df_filtered

# %%
df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
before_df['main_category'].unique()
# Out:
# array(['men', 'electronics', 'women', 'home', 'sports & outdoors',
#        'vintage & collectibles', 'beauty', 'other', 'kids', 'unknown',
#        'handmade'], dtype=object)

# %%
before_df['main_category'].value_counts()
# Out:
# main_category
# women                     663990
# beauty                    207725
# kids                      171555
# electronics               122632
# men                        93609
# home                       67831
# vintage & collectibles     46519
# other                      45329
# handmade                   30835
# sports & outdoors          25322
# unknown                     6314
# Name: count, dtype: int64

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = before_df[before_df['main_category'] == 'women']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['sub1_category'].unique()

# 결과 출력
print(category_counts)
# Out:
# ['tops & blouses' 'jewelry' 'other' 'swimwear' 'dresses' 'shoes'
#  'athletic apparel' 'jeans' 'underwear' "women's handbags"
#  'coats & jackets' 'pants' 'sweaters' 'maternity' "women's accessories"
#  'skirts' 'suits & blazers']

# %%
before_df['main_category'].value_counts().plot(kind='bar', figsize=(10, 5))
plt.xlabel('main_category')
plt.ylabel('Count')
plt.title('Category Count Bar Plot')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.show()

# %%
df.loc[df['main_category'].isin(['men', 'women', 'kids', 'other']), 'main_category'] = df['sub1_category']

# %%
df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    mlb cincinnati reds t shirt size xl                  3
# 1               1       razer blackwidow chroma keyboard                  3
# 2               2                         ava-viv blouse                  1
# 3               3                  leather horse statues                  1
# 4               4                   24k gold plated rose                  1
# ...           ...                                    ...                ...
# 1481656   1482530             free people inspired dress                  2
# 1481657   1482531          little mermaid handmade dress                  2
# 1481658   1482532  21 day fix containers and eating plan                  2
# 1481659   1482533                 world markets lanterns                  3
# 1481660   1482534          brand new lux de ville wallet                  1
#
# ...

# %%
df['main_category'].value_counts()
# Out:
# main_category
# beauty                     207725
# athletic apparel           134321
# electronics                122632
# tops & blouses             106891
# shoes                      100384
# home                        67831
# toys                        57666
# jewelry                     56807
# vintage & collectibles      46519
# women's handbags            45828
# dresses                     45730
# women's accessories         42326
# jeans                       36091
# sweaters                    35740
# underwear                   33758
# handmade                    30835
# sports & outdoors           25322
# tops                        20575
# swimwear                    18920
# men's accessories           18659
# girls 2t-5t                 18429
# coats & jackets             18376
# girls 0-24 mos              17862
# other                       17100
# boys 0-24 mos               15352
# girls (4+)                  15231
# boys (4+)                   14740
# ...

# %%
df.isna().mean()
# Out:
# train_id             0.000000
# name                 0.000000
# item_condition_id    0.000000
# category_name        0.000000
# brand_name           0.000000
# price                0.000000
# shipping             0.000000
# item_description     0.000000
# desc_length          0.000000
# positive_count       0.000000
# positive_words       0.000000
# negative_count       0.000000
# negative_words       0.000000
# main_category        0.000000
# sub1_category        0.004261
# sub2_category        0.004261
# sub3_category        0.997040
# sub4_category        0.997938
# dtype: float64

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = before_df[before_df['brand_name'] == 'pink']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['main_category'].unique()

# 결과 출력
print(category_counts)
# Out:
# ['women' 'men' 'sports & outdoors' 'vintage & collectibles' 'unknown'
#  'home' 'other' 'beauty' 'electronics' 'kids' 'handmade']

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = before_df[before_df['brand_name'] == 'pink']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['main_category'].unique()

# 결과 출력
electronics_df['main_category'].value_counts().plot(kind='bar', figsize=(10, 5))
plt.xlabel('main_category')
plt.ylabel('Count')
plt.title('Category Count Bar Plot')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.show()

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = df[df['brand_name'] == 'pink']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['main_category'].unique()

# 결과 출력
electronics_df['main_category'].value_counts().plot(kind='bar', figsize=(30, 5))
plt.xlabel('main_category')
plt.ylabel('Count')
plt.title('Category Count Bar Plot')
plt.xticks(rotation=40)  # x축 라벨 회전
plt.show()

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = df[df['brand_name'] == 'pink']

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['sub2_category'].value_counts()

# 등장 횟수가 10 이하인 카테고리만 선택
rare_categories = category_counts[category_counts >= 1000].index

# 해당 카테고리에 속하는 데이터만 필터링
# filtered_df = electronics_df[electronics_df['sub2_category'].isin(rare_categories)]

# 결과 출력
print(rare_categories)
# Out:
# Index(['t-shirts', 'pants, tights, leggings', 'panties', 'hooded',
#        'tracksuits & sweats', 'bras', 'crewneck', 'tank, cami', 'other',
#        'sports bras', 'full zip', 'jackets', 'shirts & tops', 'sandals',
#        'socks', 'backpack style'],
#       dtype='object', name='sub2_category')

# %%
# 'category' DataFrame에서 첫 번째 컬럼(category[0])이 'Electronics'인 데이터 선택
electronics_df = before_df[(before_df['brand_name'] == 'pink') & (before_df['main_category'] == 'electronics' )]

# 두 번째 컬럼(category[1])의 고유 개수를 계산
category_counts = electronics_df['sub2_category'].unique()

# 결과 출력
print(category_counts)
# Out:
# ['cell phone accessories' 'cases, covers & skins' 'headphones' 'dvd'
#  'drives, storage & media']

# %%
before_df[(before_df['brand_name'] == 'pink') & (before_df['main_category'] == 'electronics' )]
# 이게 뭐야.. 전자기기 왜 나와.. 확인해보니 다른 의미의 pink
# Out:
#          train_id                                     name  item_condition_id  \
# 73864       73914                pink case for iphone 6/6s                  1
# 275060     275197       iphone/ipod 5 victoria secret case                  3
# 670100     670460         victoria's secret pink earphones                  1
# 804964     805409                   complete buffy series!                  2
# 811139     811588                           pink key chain                  2
# 978951     979502                               hard drive                  2
# 1001637   1002202  victoria's secret pink iphone 6/6s case                  2
#
#                                              category_name brand_name  price  \
# 73864    electronics/cell phones & accessories/cell pho...       pink    8.0
# 275060   electronics/cell phones & accessories/cases, c...       pink    5.0
# 670100     electronics/tv, audio & surveillance/headphones       pink    7.0
# ...

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == 'toys' )]
# Victoria's Secret Dog 검색해보니 브랜드 다른 거임.
# Out:
#          train_id                                  name  item_condition_id  \
# 312984     313133            victoria's secret pink dog                  1
# 603220     603541        6 complete set of vs pink dogs                  2
# 623724     624056                 victoria's secret dog                  2
# 630174     630511           pink vs floating dog koozie                  1
# 656092     656451         2 sets. 1-3 pc set& 1-4pc set                  2
# 790551     790992                        5 vs pink dogs                  3
# 934939     935460            victoria's secret pink dog                  1
# 1337842   1338613  pink victoria secret dog black white                  1
# 1418459   1419294         victorias secret pink dog lot                  3
# 1460139   1460997           vs dog display for kat only                  2
#
#                              category_name brand_name  price  shipping  \
# ...

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == 'office supplies' )]
# 이것도 브랜드 다른. pink 이기만 한..

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == 'skirts' )]
# 이것도 다른...

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == 'shoes' )]

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == 'underwear' )]

# %%
before_df[(df['brand_name'] == 'pink') & (df['main_category'] == "women's handbags" )]
# Out:
#          train_id                                     name  item_condition_id  \
# 1642         1643     sale pink leopard and maroon bookbag                  3
# 1980         1981              nwot vs pink drawstring bag                  2
# 2063         2064  victoria's secret pink cosmetic bag zip                  4
# 2223         2224         vs pink campus backpack freeship                  1
# 3135         3138    vs pink weekender candle pouch bundle                  1
# ...           ...                                      ...                ...
# 1479529   1480403                      victoria secret bag                  2
# 1480379   1481253     pink victoria's secret bag- reserved                  1
# 1480450   1481324                   small pink travel case                  3
# 1480910   1481784    victoria's secret pink makeup bag new                  1
# 1481351   1482225                  vs pink draw-string bag                  1
#
# ...

# %%
df.isna().mean()
# Out:
# train_id             0.000000
# name                 0.000000
# item_condition_id    0.000000
# category_name        0.000000
# brand_name           0.000000
# price                0.000000
# shipping             0.000000
# item_description     0.000000
# desc_length          0.000000
# positive_count       0.000000
# positive_words       0.000000
# negative_count       0.000000
# negative_words       0.000000
# main_category        0.000000
# sub1_category        0.004261
# sub2_category        0.004261
# sub3_category        0.997040
# sub4_category        0.997938
# dtype: float64

# %%
df = df.fillna('unknown')

# %%
df.to_csv(r"C:\Users\eric9\Downloads\output_2.csv", index=False)

print("✅ Google Drive에 파일 저장 완료!")
# Out:
# ✅ Google Drive에 파일 저장 완료!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 한글 폰트 적용 (NanumGothic)
plt.rcParams['font.family'] = 'NanumGothic'

# 남녀 구분을 제거하는 함수 (문자열이 아닐 경우 예외 처리 추가)
def remove_gender(cat):
    if isinstance(cat, str):  # 문자열인지 확인
        parts = cat.split('/')
        if parts[0].lower() in ['men', 'women']:  # 대소문자 구분 제거
            return '/'.join(parts[1:]).strip()
    return cat  # NaN 또는 다른 데이터 타입일 경우 그대로 반환

# 'category_name' 컬럼에서 남녀 구분 제거 후 새로운 컬럼 생성
df['new_category'] = df['category_name'].apply(remove_gender)

# 각 제품 카테고리별 빈도수 계산 (상위 50개)
main_category_counts = df['new_category'].value_counts().head(50)

# 그래프 그리기 (수평 막대그래프)
plt.figure(figsize=(12, 8))
sns.barplot(x=main_category_counts.values, y=main_category_counts.index, palette="viridis")
plt.title("상위 50개 제품 카테고리 분포 (남녀 구분 제거)")
plt.xlabel("건수")
plt.ylabel("제품 카테고리")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\eric9\AppData\Local\Temp\ipykernel_24056\3836201317.py:28: UserWarning: Glyph 233 (\N{LATIN SMALL LETTER E WITH ACUTE}) missing from current font.
#   plt.tight_layout()
# C:\Users\eric9\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 233 (\N{LATIN SMALL LETTER E WITH ACUTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ddf = pd.read_csv(r"C:\Users\eric9\Downloads\output_semifinal5.csv")

ddf
# Out:
#          train_id                                    name  item_condition_id  \
# 0               1        razer blackwidow chroma keyboard                  3
# 1              46     metallic purple slime with sparkles                  1
# 2              72                  listing for aknuckles1                  1
# 3              86  jillian michaels bodyshred fitness dvd                  1
# 4             175         paw paw usb cable saver costume                  1
# ...           ...                                     ...                ...
# 1481656   1482530              free people inspired dress                  2
# 1481657   1482531           little mermaid handmade dress                  2
# 1481658   1482532   21 day fix containers and eating plan                  2
# 1481659   1482533                  world markets lanterns                  3
# 1481660   1482534           brand new lux de ville wallet                  1
#
# ...

# %%
# 상위 10개 행만 저장
ddf.head(10).to_csv(r"C:\Users\eric9\Downloads\output_head10.csv", index=False)
